# %%
import pandas,os
import matplotlib,matplotlib.pyplot
import miner_20190520 as miner

# %%
patient=['amp1q','t414','del13'] # plus trisomy 5, not found in MMRF. Trisomy 5 is better prognosis on t4;14 patients

# %% [markdown]
# # 1. Read cytogenetics

# %%
cytogenetics_file='/Users/alomana/Google Drive File Stream/My Drive/projects/MINER/shared/MINER/data/mutations/cytogenetics.csv'
df=pandas.read_csv(cytogenetics_file,index_col=0)
df
# Out:
#         MMRF_1017_1_BM  MMRF_1024_1_BM  MMRF_1024_3_BM  MMRF_1038_1_BM  \
# del13                0               0               0               0
# del17                0               0               0               0
# t414                 0               0               0               0
# t1114                0               0               0               0
# t1416                0               0               0               0
# del17p               0               0               0               0
# del1p                0               0               0               0
# amp1q                0               0               0               0
#
#         MMRF_1033_1_BM  MMRF_1007_1_BM  MMRF_1052_1_BM  MMRF_1082_1_BM  \
# del13                0               0               0               0
# del17                0               0               0               0
# t414                 0               0               0               0
# t1114                0               0               0               1
# t1416                0               0               0               1
# del17p               0               0               0               0
# del1p                0               0               0               0
# amp1q                0               0               0               0
#
#         MMRF_1094_1_BM  MMRF_1093_1_BM  ...  MMRF_2836_1_BM  MMRF_2838_1_BM  \
# del13                0               0  ...               0               1
# del17                0               0  ...               0               0
# t414                 0               0  ...               0               1
# t1114                0               0  ...               1               0
# t1416                0               0  ...               0               0
# del17p               0               0  ...               0               0
# del1p                0               0  ...               0               1
# amp1q                0               0  ...               1               0
#
#         MMRF_2839_1_BM  MMRF_2840_1_BM  MMRF_2843_1_BM  MMRF_2846_1_BM  \
# del13                1               0               0               1
# del17                0               0               0               0
# t414                 1               0               0               1
# t1114                0               0               0               0
# t1416                0               0               0               0
# del17p               0               0               0               0
# del1p                0               1               0               0
# amp1q                1               1               0               0
#
#         MMRF_2847_1_BM  MMRF_2848_1_BM  MMRF_2851_1_BM  MMRF_2853_1_BM
# del13                0               0               1               0
# del17                0               0               0               0
# t414                 0               1               0               0
# t1114                0               0               1               0
# t1416                0               0               0               0
# del17p               0               0               0               0
# del1p                0               0               0               0
# amp1q                0               1               1               1
#
# [8 rows x 1224 columns]

# %% [markdown]
# # 2. Find similar patients

# %%
dft=df.T

# %%
similar=dft[
    (dft['amp1q'] == 1) & 
    (dft['t414'] == 1) & 
    (dft['del13'] == 1) &
    #
    (dft['del17'] == 0) & 
    (dft['t1114'] == 0) &
    (dft['t1416'] == 0) &
    (dft['del17p'] == 0) &
    (dft['del1p'] == 0)
]
print(similar.shape)
similar
# Out:
# (21, 8)
#                 del13  del17  t414  t1114  t1416  del17p  del1p  amp1q
# MMRF_1433_1_BM      1      0     1      0      0       0      0      1
# MMRF_1783_2_BM      1      0     1      0      0       0      0      1
# MMRF_1974_1_BM      1      0     1      0      0       0      0      1
# MMRF_2101_1_BM      1      0     1      0      0       0      0      1
# MMRF_2621_1_BM      1      0     1      0      0       0      0      1
# MMRF_2477_1_BM      1      0     1      0      0       0      0      1
# MMRF_1300_1_BM      1      0     1      0      0       0      0      1
# MMRF_1109_1_BM      1      0     1      0      0       0      0      1
# MMRF_2297_1_BM      1      0     1      0      0       0      0      1
# MMRF_2253_1_BM      1      0     1      0      0       0      0      1
# MMRF_2604_1_BM      1      0     1      0      0       0      0      1
# MMRF_2626_1_BM      1      0     1      0      0       0      0      1
# MMRF_2636_1_BM      1      0     1      0      0       0      0      1
# MMRF_2679_1_BM      1      0     1      0      0       0      0      1
# MMRF_2682_1_BM      1      0     1      0      0       0      0      1
# MMRF_2694_1_BM      1      0     1      0      0       0      0      1
# MMRF_2706_1_BM      1      0     1      0      0       0      0      1
# MMRF_2719_1_BM      1      0     1      0      0       0      0      1
# MMRF_2767_1_BM      1      0     1      0      0       0      0      1
# MMRF_2815_1_BM      1      0     1      0      0       0      0      1
# MMRF_2839_1_BM      1      0     1      0      0       0      0      1

# %% [markdown]
# # 3. Map patients to relapse networks

# %%
# #If previous results exist, use miner.read_json to load them
# revisedClusters = miner.read_json(os.path.join(resultsDirectory,"coexpressionDictionary.json"))
# coexpressionModules = miner.read_json(os.path.join(resultsDirectory,"coexpressionModules.json"))
# regulonModules = miner.read_json(os.path.join(resultsDirectory,"regulons.json"))
# mechanisticOutput = miner.read_json(os.path.join(resultsDirectory,"mechanisticOutput.json"))
# regulonDf = pd.read_csv(os.path.join(resultsDirectory,"regulonDf.csv"),index_col=0,header=0)
# overExpressedMembersMatrix = pd.read_csv(os.path.join(resultsDirectory,"overExpressedMembers.csv"),index_col=0,header=0)
# underExpressedMembersMatrix = pd.read_csv(os.path.join(resultsDirectory,"underExpressedMembers.csv"),index_col=0,header=0)
# coherent_samples_matrix = pd.read_csv(os.path.join(resultsDirectory,"coherentMembers.csv"),index_col=0,header=0)

# %% [markdown]
# ## 3.0. Info paths

# %%
expression_data_file='/Users/alomana/Google Drive File Stream/My Drive/projects/MINER/shared/MINER/data/expression/IA12Zscore.csv'

# %% [markdown]
# ## 3.1. read data

# %%
expressionFile = os.path.join(os.path.split(os.getcwd())[0],"data","IA12Zscore.csv")
expressionData, conversionTable = miner.preprocess(expression_data_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-74818c878888> in <module>
#       1 expressionFile = os.path.join(os.path.split(os.getcwd())[0],"data","IA12Zscore.csv")
# ----> 2 expressionData, conversionTable = miner.preprocess(expression_data_file)
#
# ~/github/PSL/MM/7/miner_20190520.py in preprocess(filename)
#     414     rawExpressionZeroFiltered = removeNullRows(rawExpression)
#     415     zscoredExpression = correctBatchEffects(rawExpressionZeroFiltered)
# --> 416     expressionData, conversionTable = identifierConversion(zscoredExpression)
#     417     return expressionData, conversionTable
#     418
#
# ~/github/PSL/MM/7/miner_20190520.py in identifierConversion(expressionData, conversionTable)
#      98
#      99 def identifierConversion(expressionData,conversionTable=os.path.join("..","data","identifier_mappings.txt")):
# --> 100     idMap = pd.read_table(conversionTable)
#     101     genetypes = list(set(idMap.iloc[:,2]))
#     102     previousIndex = np.array(expressionData.index).astype(str)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1904         kwds["usecols"] = self.usecols
#    1905
# -> 1906         self._reader = parsers.TextReader(src, **kwds)
#    1907         self.unnamed_cols = self._reader.unnamed_cols
#    1908
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../data/identifier_mappings.txt' does not exist: b'../data/identifier_mappings.txt'

# %%
individual_expression_data = [expressionData.iloc[:,i] for i in range(50)]
_ = plt.boxplot(individual_expression_data)
matplotlib.pyplot.title("Patient expression profiles",FontSize=14)
matplotlib.pyplot.ylabel("Relative expression",FontSize=14)
matplotlib.pyplot.xlabel("Sample ID",FontSize=14)
matplotlib.pyplot.figure()
_ = plt.hist(expressionData.iloc[0,:],bins=100,alpha=0.75)
matplotlib.pyplot.title("Expression of single gene",FontSize=14)
matplotlib.pyplot.ylabel("Frequency",FontSize=14)
matplotlib.pyplot.xlabel("Relative expression",FontSize=14)
matplotlib.pyplot.figure()
_ = plt.hist(expressionData.iloc[:,0],bins=200,color=[0,0.4,0.8],alpha=0.75)
matplotlib.pyplot.ylim(0,350)
matplotlib.pyplot.title("Expression of single patient sample",FontSize=14)
matplotlib.pyplot.ylabel("Frequency",FontSize=14)
matplotlib.pyplot.xlabel("Relative expression",FontSize=14)

# %% [markdown]
# # 4. Map patients to states
